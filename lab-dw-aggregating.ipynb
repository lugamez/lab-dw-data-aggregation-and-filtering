# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
import numpy as np

# %%
# Read file

customer_data = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')
display(customer_data.head())
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
# Review number of rows and columns

customer_data.shape
# Out:
# (10910, 26)

# %%
# Review if there are NaN values

customer_data.isna().sum()
# Out:
# Unnamed: 0                          0
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# EmploymentStatus                    0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# ...

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
customer_data_new = customer_data[(customer_data['Total Claim Amount'] > 1000) & (customer_data['Response'] == 'Yes')]
display(customer_data_new)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 189           189  OK31456  California             11009.130490      Yes
# 236           236  YJ16163      Oregon             11009.130490      Yes
# 419           419  GW43195      Oregon             25807.063000      Yes
# 442           442  IP94270     Arizona             13736.132500      Yes
# 587           587  FJ28407  California              5619.689084      Yes
# ...           ...      ...         ...                      ...      ...
# 10351       10351  FN44127      Oregon              3508.569533      Yes
# 10373       10373  XZ64172      Oregon             10963.957230      Yes
# 10487       10487  IX60941      Oregon              3508.569533      Yes
# 10565       10565  QO62792      Oregon              7840.165778      Yes
# 10708       10708  CK39096      Oregon              5619.689084      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
customer_data[(customer_data['Response'] == 'Yes')].groupby(['Policy Type', 'Gender']).agg({'Total Claim Amount':'mean'}).round(2)
# Out:
#                        Total Claim Amount
# Policy Type    Gender
# Corporate Auto F                   433.74
#                M                   408.58
# Personal Auto  F                   452.97
#                M                   457.01
# Special Auto   F                   453.28
#                M                   429.53

# %% [markdown]
# Among the people that responded "Yes" to the marketing campaign, we can take the following conclusions:
#
# 1. Women with a Corporate Auto or Special Auto policy have a higher claim amount than men with the same one
# 2. Men with a Personal Auto policy have a higher claim amount than women with the same one
# 3. There's a 5 point difference in the total claim amount between those women and men that have a Personal Auto policy. For the other policies, the difference increases 5x in comparison with the Personal policy.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
# As 631 customers (5% of the dataframe) don't have information about the state, we will fill these rows with the mode (California)

customer_data['State'].mode()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %%
# Fill rows from customers with NaN as State

customer_data['State'].fillna('California', inplace=True)

# %%
# Total number of customer who have policies in each state

customer_per_state = customer_data.groupby(['State']).agg({'Customer':'count'})
display(customer_per_state)
# Out:
#             Customer
# State
# Arizona         1937
# California      4183
# Nevada           993
# Oregon          2909
# Washington       888

# %%
# Results filtered to only include states where there are more than 500 customers

customer_per_state[(customer_per_state['Customer'] > 500)]
# Out:
#             Customer
# State
# Arizona         1937
# California      4183
# Nevada           993
# Oregon          2909
# Washington       888

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
customer_data.groupby(['Education','Gender']).agg({'Customer Lifetime Value':['max', 'min', 'median']}).round(2)
# Out:
#                             Customer Lifetime Value
#                                                 max      min   median
# Education            Gender
# Bachelor             F                     73225.96  1904.00  5640.51
#                      M                     67907.27  1898.01  5548.03
# College              F                     61850.19  1898.68  5623.61
#                      M                     61134.68  1918.12  6005.85
# Doctor               F                     44856.11  2395.57  5332.46
#                      M                     32677.34  2267.60  5577.67
# High School or Below F                     55277.45  2144.92  6039.55
#                      M                     83325.38  1940.98  6286.73
# Master               F                     51016.07  2417.78  5729.86
#                      M                     50568.26  2272.31  5579.10

# %% [markdown]
# We can get some conclusions from the previous data:
#
# 1. We can find the biggest CLV (83k) among men with a High School or below education level, followed by women with a Bachelor degree (73k). This mean that, throughout the whole customer lifetime cycle, they will bring to the company that amount of revenue.
# 2. Females with a Bachelor degree are the ones that will provide a smallest CLV (1.9k) to the company, followed by men with a College degree (1.9k). This mean that, throughout the whole customer lifetime cycle, they will bring to the company that amount of revenue.
# 3. If we look at both women and men, 50% of them bring the following revenue to the company:
# a. Bachelor degree: 55k/56k
# b. College degree: 56k/60k
# c. Doctor: 53k/55k
# d. High School or Below: 60k/62k
# e. Master: 55k/57k

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %%
# Make a copy of the dataframe

customer_data_copy = customer_data.copy()

# %%
# Extract the month from the column "Efective To Date"

customer_data_copy[['Policy - Month Eff', 'Policy - Day Eff', 'Policy - Year Eff']] = customer_data_copy['Effective To Date'].str.split('/', expand=True)
display(customer_data_copy)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
# Create pivot

policies_state_month = customer_data_copy.pivot_table(index='State', columns='Policy - Month Eff', values='Number of Policies', aggfunc='count')
display(policies_state_month)
# Out:
# Policy - Month Eff     1     2
# State
# Arizona             1008   929
# California          2231  1952
# Nevada               551   442
# Oregon              1565  1344
# Washington           463   425

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %%
# Sort values in descending order

top_states = policies_state_month.sort_values(by=['1','2'], ascending=False)
display(top_states)
# Out:
# Policy - Month Eff     1     2
# State
# California          2231  1952
# Oregon              1565  1344
# Arizona             1008   929
# Nevada               551   442
# Washington           463   425

# %%
# Show 3 states with the highest number of policies sold

top_states.iloc[:3]
# Out:
# Policy - Month Eff     1     2
# State
# California          2231  1952
# Oregon              1565  1344
# Arizona             1008   929

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# Filter by those customers with response

customer_data_response = customer_data[(customer_data['Response'] == 'Yes')]
display(customer_data_response)
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 3               3  XL78013      Oregon             22332.439460      Yes
# 8               8  FM55990  California              5989.773931      Yes
# 15             15  CW49887  California              4626.801093      Yes
# 19             19  NJ54277  California              3746.751625      Yes
# 27             27  MQ68407      Oregon              4376.363592      Yes
# ...           ...      ...         ...                      ...      ...
# 10844       10844  FM31768     Arizona              5979.724161      Yes
# 10852       10852  KZ80424  Washington              8382.478392      Yes
# 10872       10872  XT67997  California              5979.724161      Yes
# 10887       10887  BY78730      Oregon              8879.790017      Yes
# 10897       10897  MM70762     Arizona              9075.768214      Yes
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
# Count by sales channel

customer_data_response.groupby(['Sales Channel']).agg({'Response':'count'})
# Out:
#                Response
# Sales Channel
# Agent               742
# Branch              326
# Call Center         221
# Web                 177
